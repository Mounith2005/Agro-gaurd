# %%
import os

def total_files(folder_path):
    num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
    return num_files

train_files_Tomato_healthy = "Dataset/Train/Train/Tomato_healthy"
train_files_Tomato__Target_Spot = "Dataset/Train/Train/Tomato__Target_Spot"

train_files_Tomato__Tomato_YellowLeaf__Curl_Virus = "Dataset/Train/Train/Tomato__Tomato_YellowLeaf__Curl_Virus"
train_files_Tomato__Bacterial_spot = "Dataset/Train/Train/Tomato__Bacterial_spot"
train_files_Tomato__Early_blight = "Dataset/Train/Train/Tomato__Early_blight"
train_files_Tomato__Late_blight = "Dataset/Train/Train/Tomato__Late_blight"
train_files_Tomato__Leaf_Mold = "Dataset/Train/Train/Tomato__Leaf_Mold"
train_files_Tomato__Septoria_leaf_spot = "Dataset/Train/Train/Tomato__Septoria_leaf_spot"
train_files_Tomato__Spider_mites_Two_spotted_spider_mite = "Dataset/Train/Train/Tomato__Spider_mites_Two_spotted_spider_mite"


test_files_Tomato_healthy = "Dataset/Test/Test/Tomato_healthy"
test_files_Tomato__Target_Spot = "Dataset/Test/Test/Tomato__Target_Spot"

test_files_Tomato__Tomato_YellowLeaf__Curl_Virus = "Dataset/Test/Test/Tomato__Tomato_YellowLeaf__Curl_Virus"
test_files_Tomato__Bacterial_spot = "Dataset/Test/Test/Tomato__Bacterial_spot"
test_files_Tomato__Early_blight = "Dataset/Test/Test/Tomato__Early_blight"
test_files_Tomato__Late_blight = "Dataset/Test/Test/Tomato__Late_blight"
test_files_Tomato__Leaf_Mold = "Dataset/Test/Test/Tomato__Leaf_Mold"
test_files_Tomato__Septoria_leaf_spot = "Dataset/Test/Test/Tomato__Septoria_leaf_spot"
test_files_Tomato__Spider_mites_Two_spotted_spider_mite = "Dataset/Test/Test/Tomato__Spider_mites_Two_spotted_spider_mite"


validtest_files_Tomato_healthy = "Dataset/Validation/Validation/Tomato_healthy"
valid_files_Tomato__Target_Spot = "Dataset/Validation/Validation/Tomato__Target_Spot"

valid_files_Tomato__Tomato_YellowLeaf__Curl_Virus = "Dataset/Validation/Validation/Tomato__Tomato_YellowLeaf__Curl_Virus"
valid_files_Tomato__Bacterial_spot = "Dataset/Validation/Validation/Tomato__Bacterial_spot"
valid_files_Tomato__Early_blight = "Dataset/Validation/Validation/Tomato__Early_blight"
valid_files_Tomato__Late_blight = "Dataset/Validation/Validation/Tomato__Late_blight"
valid_files_Tomato__Leaf_Mold = "Dataset/Validation/Validation/Tomato__Leaf_Mold"
valid_files_Tomato__Septoria_leaf_spot = "Dataset/Validation/Validation/Tomato__Septoria_leaf_spot"
valid_files_Tomato__Spider_mites_Two_spotted_spider_mite = "Dataset/Validation/Validation/Tomato__Spider_mites_Two_spotted_spider_mite"

print("Number of Tomato_healthy leaf images in training set", total_files(train_files_Tomato_healthy))
print("Number of Tomato Target Spot images in training set", total_files(train_files_Tomato__Target_Spot))

print("Number of Tomato Yellow Leaf Curl Virus images in training set", total_files(train_files_Tomato__Tomato_YellowLeaf__Curl_Virus))
print("Number of Tomato Bacterial Spot images in training set", total_files(train_files_Tomato__Bacterial_spot))
print("Number of Tomato Early Blight images in training set", total_files(train_files_Tomato__Early_blight))
print("Number of Tomato Late Blight images in training set", total_files(train_files_Tomato__Late_blight))
print("Number of Tomato Leaf Mold images in training set", total_files(train_files_Tomato__Leaf_Mold))
print("Number of Tomato Septoria Leaf Spot images in training set", total_files(train_files_Tomato__Septoria_leaf_spot))
print("Number of Tomato Spider Mite images in training set", total_files(train_files_Tomato__Spider_mites_Two_spotted_spider_mite))


print("========================================================")

print("Number of Tomato_healthy leaf images in test set", total_files(test_files_Tomato_healthy))
print("Number of Tomato Target Spot images in test set", total_files(test_files_Tomato__Target_Spot))

print("Number of Tomato Yellow Leaf Curl Virus images in test set", total_files(test_files_Tomato__Tomato_YellowLeaf__Curl_Virus))
print("Number of Tomato Bacterial Spot images in test set", total_files(test_files_Tomato__Bacterial_spot))
print("Number of Tomato Early Blight images in test set", total_files(test_files_Tomato__Early_blight))
print("Number of Tomato Late Blight images in test set", total_files(test_files_Tomato__Late_blight))
print("Number of Tomato Leaf Mold images in test set", total_files(test_files_Tomato__Leaf_Mold))
print("Number of Tomato Septoria Leaf Spot images in test set", total_files(test_files_Tomato__Septoria_leaf_spot))
print("Number of Tomato Spider Mite images in test set", total_files(test_files_Tomato__Spider_mites_Two_spotted_spider_mite))


print("========================================================")


print("Number of Tomato_healthy leaf images in validation set", total_files(validtest_files_Tomato_healthy))
print("Number of Tomato Target Spot images in validation set", total_files(valid_files_Tomato__Target_Spot))

print("Number of Tomato Yellow Leaf Curl Virus images in validation set", total_files(valid_files_Tomato__Tomato_YellowLeaf__Curl_Virus))
print("Number of Tomato Bacterial Spot images in validation set", total_files(valid_files_Tomato__Bacterial_spot))
print("Number of Tomato Early Blight images in validation set", total_files(valid_files_Tomato__Early_blight))
print("Number of Tomato Late Blight images in validation set", total_files(valid_files_Tomato__Late_blight))
print("Number of Tomato Leaf Mold images in validation set", total_files(valid_files_Tomato__Leaf_Mold))
print("Number of Tomato Septoria Leaf Spot images in validation set", total_files(valid_files_Tomato__Septoria_leaf_spot))
print("Number of Tomato Spider Mite images in validation set", total_files(valid_files_Tomato__Spider_mites_Two_spotted_spider_mite))
# Out:
# Number of Tomato_healthy leaf images in training set 1594
# Number of Tomato Target Spot images in training set 1404
# Number of Tomato Yellow Leaf Curl Virus images in training set 3209
# Number of Tomato Bacterial Spot images in training set 2129
# Number of Tomato Early Blight images in training set 1002
# Number of Tomato Late Blight images in training set 1909
# Number of Tomato Leaf Mold images in training set 952
# Number of Tomato Septoria Leaf Spot images in training set 1773
# Number of Tomato Spider Mite images in training set 1677
# ...
# Number of Tomato_healthy leaf images in test set 1594
# Number of Tomato Target Spot images in test set 1404
# Number of Tomato Yellow Leaf Curl Virus images in test set 3209
# Number of Tomato Bacterial Spot images in test set 2129
# Number of Tomato Early Blight images in test set 1002
# Number of Tomato Late Blight images in test set 1909
# Number of Tomato Leaf Mold images in test set 952
# ...

# %%
from PIL import Image
import IPython.display as display

image_path = 'Dataset/Train/Train/Tomato_healthy/87a77f4d-38bd-42dc-bdd3-5f2a1fa95ca7___GH_HL Leaf 469.3.jpg'

with open(image_path, 'rb') as f:
    display.display(display.Image(data=f.read(), width=500))

# %%
from IPython import display

image_path = r"Dataset/Train/Train/Tomato__Bacterial_spot/33028adc-9dc2-4ac3-a7b9-7094200264f6___GCREC_Bact.Sp 3162.JPG"

with open(image_path, 'rb') as f:
    display.display(display.Image(data=f.read(), width=500))

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory('Dataset/Train/Train',
                                                    target_size=(225, 225),
                                                    batch_size=32,
                                                    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory('Dataset/Validation/Validation',
                                                        target_size=(225, 225),
                                                        batch_size=32,
                                                        class_mode='categorical')
# Out:
# Found 15648 images belonging to 9 classes.
# Found 15648 images belonging to 9 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense


model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(225, 225, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(9, activation='softmax'))
# Out:
# c:\Users\admin\Downloads\plant_disease_detection-main\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    batch_size=16,
    epochs=5,
    validation_data=validation_generator,
    validation_batch_size=16
)
# Out:
# c:\Users\admin\Downloads\plant_disease_detection-main\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 489/489 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5493 - loss: 1.4361
# c:\Users\admin\Downloads\plant_disease_detection-main\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# ...

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import seaborn as sns
sns.set_theme()
sns.set_context("poster")

figure(figsize=(25, 25), dpi=100)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

def preprocess_image(image_path, target_size=(225, 225)):
    img = load_img(image_path, target_size=target_size)
    x = img_to_array(img)
    x = x.astype('float32') / 255.
    x = np.expand_dims(x, axis=0)
    return x

x = preprocess_image('Dataset/Test/Test/Tomato__Leaf_Mold/0a9b3ff4-5343-4814-ac2c-fdb3613d4e4d___Crnl_L.Mold 6559.jpg')

# %%
predictions = model.predict(x)
predictions[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# array([2.1487860e-04, 1.0175674e-04, 1.5177849e-05, 9.5709580e-01,
#        4.2440619e-02, 1.1696648e-04, 1.1628924e-06, 8.6223054e-07,
#        1.2707996e-05], dtype=float32)

# %%
labels = train_generator.class_indices
labels = {v: k for k, v in labels.items()}
labels
# Out:
# {0: 'Tomato__Bacterial_spot',
#  1: 'Tomato__Early_blight',
#  2: 'Tomato__Late_blight',
#  3: 'Tomato__Leaf_Mold',
#  4: 'Tomato__Septoria_leaf_spot',
#  5: 'Tomato__Spider_mites_Two_spotted_spider_mite',
#  6: 'Tomato__Target_Spot',
#  7: 'Tomato__Tomato_YellowLeaf__Curl_Virus',
#  8: 'Tomato_healthy'}

# %%
predicted_label = labels[np.argmax(predictions)]
print(predicted_label)
# Out:
# Tomato__Leaf_Mold
